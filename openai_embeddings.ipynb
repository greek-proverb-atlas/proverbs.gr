# %%
import pandas as pd
import numpy as np

import openai_config
from openai import OpenAI

client = OpenAI(
    api_key=openai_config.api_key
)

from tqdm.auto import tqdm
tqdm.pandas()

import seaborn as sns
from sklearn.manifold import TSNE

import os

# %%
df = pd.read_csv('data/balanced_corpus.csv')
df
# Out:
#        Unnamed: 0                                               text  \
# 0          105697                               Γέλια σαν κομπολόγια
# 1            8413                        Καρδίαν καθαράν θέλ' ο Θεός
# 2            7684                             Ου Θεός κι ου γείτονας
# 3           18546            Θέλει να κρυφθή πίσω από το δάχτυλό του
# 4           94001      Όλοι κλαίν' τα χάλια τ'ς κι ο μυλωνάς τη δέσι
# ...           ...                                                ...
# 11495      101735                          Παστρζικό τσανα τσ' έναι!
# 11496      101233        Κάλλιο γεναίκα κάμισσα, πέρζι πολυπροικούσα
# 11497      101612  Όγοιος κάθεται στη στερζά τσαί θάλασσα γερεύει...
# 11498      101762                          Πήε στ' δαιμόνου τ' μάννα
# 11499      101191                   Θα σε κάνου να κατουρζήσεις αίμα
#
#                         place                                        uri  \
# ...

# %%
df['area'].value_counts()
# Out:
# area
# Ήπειρος            500
# Κεφαλληνία         500
# Ρόδος              500
# Πόντος             500
# Νάξος              500
# Μικρά Ασία         500
# Μακεδονία          500
# Λακωνία            500
# Λέσβος             500
# Κύπρος             500
# Κρήτη              500
# Κάρπαθος           500
# Αιτωλία            500
# Ιωάννινα           500
# Θράκη              500
# Θεσπρωτία          500
# Εύβοια             500
# Επτάνησος          500
# Αχαΐα              500
# Αρκαδία            500
# Ανατολική Θράκη    500
# Αμοργός            500
# Σκύρος             500
# Name: count, dtype: int64

# %%
def get_embedding(text, model):
   embedding_response = client.embeddings.create(input = [text], model=model)
   return embedding_response.data[0].embedding

# %%
def create_embeddings(model, df):
  embeddings = df['text'].progress_apply(
    lambda x: get_embedding(x, model)).to_list()
  df_emb = pd.DataFrame(embeddings)
  return df_emb

# %%
if not os.path.exists("openai_embeddings.csv"):
    df_emb = create_embeddings('text-embedding-3-large', df)
    df_emb.to_csv('openai_embeddings.csv', index=False)
    df_emb.to_pickle('openai_embeddings.pkl')
else:
    df_emb = pd.read_csv("openai_embeddings.csv")

df_emb
# Out:
#   0%|          | 0/11500 [00:00<?, ?it/s]
#            0         1         2         3         4         5         6     \
# 0      0.007616 -0.029212 -0.023626 -0.000502  0.030085  0.031278 -0.046815
# 1      0.015828 -0.021061  0.007283  0.023664  0.006655  0.021191 -0.023430
# 2     -0.010236 -0.011024 -0.004392  0.033492 -0.020695  0.030534  0.009308
# 3     -0.013338 -0.002655  0.012541 -0.014041  0.054608 -0.005294  0.019907
# 4      0.013959 -0.013528  0.007281  0.007295  0.016312 -0.017853 -0.003292
# ...         ...       ...       ...       ...       ...       ...       ...
# 11495 -0.021441 -0.031316 -0.014829  0.027737  0.037885 -0.005150  0.000671
# 11496 -0.044142  0.017005 -0.015369  0.052845  0.041985  0.035925 -0.063753
# 11497 -0.041707 -0.034759  0.005535  0.011397  0.056120  0.017188  0.004472
# 11498 -0.018636 -0.023001 -0.003325  0.012509  0.022376  0.010965  0.013479
# 11499 -0.001711 -0.039434  0.002487  0.013532  0.036103  0.051443 -0.012861
#
# ...

# %%
tsne = TSNE(n_components=2, random_state=0).fit_transform(df_emb)
ax = sns.scatterplot(x=tsne[:, 0], 
                     y=tsne[:, 1], 
                     s=5,
                     hue=np.array(df['area'].to_list()))
sns.move_legend(ax, 'upper left', bbox_to_anchor=(1, 1))
